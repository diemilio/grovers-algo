# %%
import numpy as np
from fractions import Fraction
import matplotlib.pyplot as plt

# %%
def grover(n,marked,m):
    
    N = 2**n                     # Number of elements
    elems = np.arange(N)         # Array of elements
    
    # Generate array of probability amplitudes, all equal to 1/(2^(n/2))
    amplitudes = 1/(2**(n/2))*np.ones(len(elems))
    
    # Perform phase inversion and inversion about the mean m times
    for i in range(m):

        # phase inversion
        amplitudes[marked] = -amplitudes[marked]

        # Select arbitrary unmarked element (either 0 or 1)
        if marked == 0:
            arb_unmrkd = 1
        else:
            arb_unmrkd = 0

        # calculate 2*mean
        mean_2x = 2/N*((N-1)*amplitudes[arb_unmrkd] + amplitudes[marked])

        # Calculate new probability amplitudes after inv. about mean
        for j in range(len(amplitudes)):
            amplitudes[j] = mean_2x - amplitudes[j]

    fig, ax = plt.subplots()
    ax.bar(elems,amplitudes)

# %%
n = 4       # Number of qubits
# m = 1     # Number of times to perform phase inv and inv about mean

marked = 0  # Marked element (any decimal value between 0 and 2**n)


grover(n,marked,1)

# %%
grover(n,marked,2)

# %%
grover(n,marked,3)

# %%
grover(n,marked,4)

# %%
grover(n,marked,5)

# %%
grover(n,marked,6)

# %%
grover(n,marked,7)

# %%
grover(n,marked,8)

# %%
grover(n,marked,9)

# %%
grover(n,marked,10)

# %%
grover(n,marked,11)

# %%
grover(n,marked,12)

# %%
grover(n,marked,13)

# %%
grover(n,marked,14)

# %%
grover(n,marked,15)
